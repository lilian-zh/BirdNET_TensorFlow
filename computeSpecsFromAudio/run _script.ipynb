# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-d5df0069828e> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     113       force_remount=force_remount,
#     114       timeout_ms=timeout_ms,
# --> 115       ephemeral=True)
#     116
#     117
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, use_metadata_server, ephemeral)
#     192       raise ValueError('Mountpoint must not be a symlink')
#     193     if _os.path.isdir(mountpoint) and _os.listdir(mountpoint):
# --> 194       raise ValueError('Mountpoint must not already contain files')
# ...

# %%
import os
import random
import pickle

audio_dir = "/content/gdrive/MyDrive/RP/DataSet/audio_Troglodytes_troglodytes"
files = os.listdir(audio_dir)
# print(files)

random.seed(42)
train_tt = random.sample(files, int(len(files)*0.8))
val_test = list(set(files).difference(set(train_tt)))
random.seed(42) 
val_tt = random.sample(val_test, int(len(files)*0.1))
test_tt = list(set(val_test).difference(set(val_tt)))

# with open('/content/gdrive/MyDrive/RP/DataSet/pkl/train_tt.pkl', 'wb') as f:
#     pickle.dump(train_tt, f)
# with open('/content/gdrive/MyDrive/RP/DataSet/pkl/val_tt.pkl', 'wb') as f:
#     pickle.dump(val_tt, f)
# with open('/content/gdrive/MyDrive/RP/DataSet/pkl/test_tt.pkl', 'wb') as f:
#     pickle.dump(test_tt, f)

# %%
# !python /content/gdrive/MyDrive/RP/Li/computeSpecsFromAudio/getSpecs.py
# Out:
# 100% 50/50 [00:39<00:00,  1.26it/s]
# SUCCESSFULLY EXTRACTED 241 SPECTROGRAMS
# Traceback (most recent call last):
#   File "/content/gdrive/MyDrive/RP/Li/computeSpecsFromAudio/getSpecs.py", line 155, in <module>
#     with open('/content/drive/MyDrive/RP/DataSet/pkl/val_tt_spec.pkl', 'wb') as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/RP/DataSet/pkl/val_tt_spec.pkl'

# %%
spec_dir = "/content/gdrive/MyDrive/RP/DataSet/detected_specs/non-event"
non_events = os.listdir(spec_dir)
# print(non_events)
train_tt_spec=[]
for event in non_events:
  # print(event.split("_")[0]+".png")
  if event.split("_")[0]+".png" in train_tt:
    train_tt_spec.append()
# print(train_tt_spec)

train_tt = pickle.load(open("/content/gdrive/MyDrive/RP/DataSet/pkl/train_tt.pkl",'rb'))
print(train_tt)
# Out:
# ['XC651491.mp3', 'XC577730.mp3', 'XC595584.mp3', 'XC639108.mp3', 'XC710226.mp3', 'XC556056.mp3', 'XC561968.mp3', 'XC574405.MP3', 'XC639382.mp3', 'XC579360.mp3', 'XC648350.mp3', 'XC604582.mp3', 'XC621603.mp3', 'XC666953.mp3', 'XC581752.mp3', 'XC662515.mp3', 'XC688611.mp3', 'XC595579.mp3', 'XC595580.mp3', 'XC581099.mp3', 'XC562393.mp3', 'XC560500.mp3', 'XC672470.mp3', 'XC659808.mp3', 'XC595583.mp3', 'XC666820.mp3', 'XC564897.mp3', 'XC642697.mp3', 'XC649348.mp3', 'XC643732.mp3', 'XC608330.mp3', 'XC689491.mp3', 'XC562383.mp3', 'XC685931.mp3', 'XC662690.mp3', 'XC709607.mp3', 'XC630308.mp3', 'XC624243.mp3', 'XC597428.mp3', 'XC637966.mp3', 'XC630604.mp3', 'XC571730.mp3', 'XC643988.mp3', 'XC611185.mp3', 'XC703500.mp3', 'XC621087.mp3', 'XC572146.mp3', 'XC562422.mp3', 'XC637079.mp3', 'XC703524.mp3', 'XC606116.mp3', 'XC612748.mp3', 'XC696513.mp3', 'XC581054.mp3', 'XC701407.mp3', 'XC627579.mp3', 'XC703137.mp3', 'XC659494.mp3', 'XC711357.mp3', 'XC630510.mp3', 'XC594183.mp3', 'XC640272.MP3', 'XC68
# ...
